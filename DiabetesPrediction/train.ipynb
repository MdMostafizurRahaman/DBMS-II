# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/home/asif/DBMS-II/DiabetesPrediction/diabetes.xls")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
pregnancies = df.Pregnancies.values
glucose = df.Glucose.values
bloodPressure = df.BloodPressure.values
skinThickness = df.SkinThickness.values
insulin = df.Insulin.values
bmi = df.BMI.values
diabetesPedigreeFunction = df.DiabetesPedigreeFunction.values
age = df.Age.values
isDiabetes = df.Outcome.values
print(isDiabetes[:5])
# Out:
# [1 0 1 0 1]

# %%
pregnancies_NoDiabetes = {}
glucose_Diabetes = {}
bloodPressure_Diabetes = {}
skinThickness_Diabetes = {}
insulin_Diabetes = {}
bmi_Diabetes = {}
diabetesPedigreeFunction_Diabetes = {}
age_Diabetes = {}

# %%
pregnancies_NoDiabetes = {}
glucose_NoDiabetes = {}
bloodPressure_NoDiabetes = {}
skinThickness_NoDiabetes = {}
insulin_NoDiabetes = {}
bmi_NoDiabetes = {}
diabetesPedigreeFunction_NoDiabetes = {}
age_NoDiabetes = {}

# %%
for i in range(len(isDiabetes)):
    if isDiabetes[i] == 1:
        # pregnancies
        temp = pregnancies[i]
        if temp in pregnancies_NoDiabetes:
            pregnancies_NoDiabetes[temp] += 1
        else:
            pregnancies_NoDiabetes[temp] = 1
        
        # glucose
        temp = glucose[i]
        if temp in glucose_Diabetes:
            glucose_Diabetes[temp] += 1
        else:
            glucose_Diabetes[temp] = 1
        
        # bloodPressure
        temp = bloodPressure[i]
        if temp in bloodPressure_Diabetes:
            bloodPressure_Diabetes[temp] += 1
        else:
            bloodPressure_Diabetes[temp] = 1
        
        # skinThickness
        temp = skinThickness[i]
        if temp in skinThickness_Diabetes:
            skinThickness_Diabetes[temp] += 1
        else:
            skinThickness_Diabetes[temp] = 1
        
        # insulin
        temp = insulin[i]
        if temp in insulin_Diabetes:
            insulin_Diabetes[temp] += 1
        else:
            insulin_Diabetes[temp] = 1
        
        # bmi
        temp = bmi[i]
        if temp in bmi_Diabetes:
            bmi_Diabetes[temp] += 1
        else:
            bmi_Diabetes[temp] = 1
        
        # diabetesPedigreeFunction
        temp = diabetesPedigreeFunction[i]
        if temp in diabetesPedigreeFunction_Diabetes:
            diabetesPedigreeFunction_Diabetes[temp] += 1
        else:
            diabetesPedigreeFunction_Diabetes[temp] = 1
        
        # age
        temp = age[i]
        if temp in age_Diabetes:
            age_Diabetes[temp] += 1
        else:
            age_Diabetes[temp] = 1

    else:
        # pregnencies
        temp = pregnancies[i]
        if temp in pregnancies_NoDiabetes:
            pregnancies_NoDiabetes[temp] += 1
        else:
            pregnancies_NoDiabetes[temp] = 1
        
        # glucose
        temp = glucose[i]
        if temp in glucose_NoDiabetes:
            glucose_NoDiabetes[temp] += 1
        else:
            glucose_NoDiabetes[temp] = 1
        
        # bloodPressure
        temp = bloodPressure[i]
        if temp in bloodPressure_NoDiabetes:
            bloodPressure_NoDiabetes[temp] += 1
        else:
            bloodPressure_NoDiabetes[temp] = 1
        
        # skinThickness
        temp = skinThickness[i]
        if temp in skinThickness_NoDiabetes:
            skinThickness_NoDiabetes[temp] += 1
        else:
            skinThickness_NoDiabetes[temp] = 1
        
        # insulin
        temp = insulin[i]
        if temp in insulin_NoDiabetes:
            insulin_NoDiabetes[temp] += 1
        else:
            insulin_NoDiabetes[temp] = 1
        
        # bmi
        temp = bmi[i]
        if temp in bmi_NoDiabetes:
            bmi_NoDiabetes[temp] += 1
        else:
            bmi_NoDiabetes[temp] = 1
        
        # diabetesPedigreeFunction
        temp = diabetesPedigreeFunction[i]
        if temp in diabetesPedigreeFunction_NoDiabetes:
            diabetesPedigreeFunction_NoDiabetes[temp] += 1
        else:
            diabetesPedigreeFunction_NoDiabetes[temp] = 1
        
        # age
        temp = age[i]
        if temp in age_NoDiabetes:
            age_NoDiabetes[temp] += 1
        else:
            age_NoDiabetes[temp] = 1

# %%
print(age_Diabetes)
# Out:
# {50: 5, 32: 9, 33: 10, 26: 8, 53: 4, 54: 4, 34: 4, 59: 2, 51: 5, 31: 13, 41: 13, 29: 13, 43: 11, 28: 10, 46: 7, 27: 8, 56: 2, 25: 14, 58: 3, 39: 3, 42: 7, 38: 10, 37: 6, 60: 2, 24: 8, 61: 1, 23: 7, 40: 6, 62: 2, 30: 6, 36: 10, 47: 4, 57: 1, 52: 7, 21: 5, 66: 2, 22: 11, 49: 3, 44: 5, 35: 5, 67: 1, 45: 8, 55: 1, 70: 1, 48: 1}

# %%
prob_pregnancies_Diabetes = {}
prob_glucose_Diabetes = {}
prob_bloodPressure_Diabetes = {}
prob_skinThickness_Diabetes = {}
prob_insulin_Diabetes = {}
prob_bmi_Diabetes = {}
prob_diabetesPedigreeFunction_Diabetes = {}
prob_age_Diabetes = {}

# %%
# pregnencies
total = sum(pregnancies_NoDiabetes.values())
prob_pregnancies_Diabetes = {key: value / total for key, value in pregnancies_NoDiabetes.items()}

# glucose
total = sum(glucose_Diabetes.values())
prob_glucose_Diabetes  = {key: value / total for key, value in glucose_Diabetes.items()}

# bloodPressure
total = sum(bloodPressure_Diabetes.values())
prob_bloodPressure_Diabetes  = {key: value / total for key, value in bloodPressure_Diabetes.items()}


# skinThickness
total = sum(skinThickness_Diabetes.values())
prob_skinThickness_Diabetes  = {key: value / total for key, value in skinThickness_Diabetes.items()}

# insulin
total = sum(insulin_Diabetes.values())
prob_insulin_Diabetes  = {key: value / total for key, value in insulin_Diabetes.items()}

# bmi
total = sum(bmi_Diabetes.values())
prob_bmi_Diabetes  = {key: value / total for key, value in bmi_Diabetes.items()}

# diabetesPedigreeFunction
total = sum(diabetesPedigreeFunction_Diabetes.values())
prob_diabetesPedigreeFunction_Diabetes  = {key: value / total for key, value in diabetesPedigreeFunction_Diabetes.items()}

# age
total = sum(age_Diabetes.values())
prob_age_Diabetes  = {key: value / total for key, value in age_Diabetes.items()}

# %%
prob_pregnancies_NoDiabetes = {}
prob_glucose_NoDiabetes = {}
prob_bloodPressure_NoDiabetes = {}
prob_skinThickness_NoDiabetes = {}
prob_insulin_NoDiabetes = {}
prob_bmi_NoDiabetes = {}
prob_diabetesPedigreeFunction_NoDiabetes = {}
prob_age_NoDiabetes = {}

# %%
# pregnencies
total = sum(pregnancies_NoDiabetes.values())
prob_pregnancies_NoDiabetes = {key: value / total for key, value in pregnancies_NoDiabetes.items()}

# glucose
total = sum(glucose_NoDiabetes.values())
prob_glucose_NoDiabetes  = {key: value / total for key, value in glucose_NoDiabetes.items()}

# bloodPressure
total = sum(bloodPressure_NoDiabetes.values())
prob_bloodPressure_NoDiabetes  = {key: value / total for key, value in bloodPressure_NoDiabetes.items()}


# skinThickness
total = sum(skinThickness_NoDiabetes.values())
prob_skinThickness_NoDiabetes  = {key: value / total for key, value in skinThickness_NoDiabetes.items()}

# insulin
total = sum(insulin_NoDiabetes.values())
prob_insulin_NoDiabetes  = {key: value / total for key, value in insulin_NoDiabetes.items()}

# bmi
total = sum(bmi_NoDiabetes.values())
prob_bmi_NoDiabetes  = {key: value / total for key, value in bmi_NoDiabetes.items()}

# diabetesPedigreeFunction
total = sum(diabetesPedigreeFunction_NoDiabetes.values())
prob_diabetesPedigreeFunction_NoDiabetes  = {key: value / total for key, value in diabetesPedigreeFunction_NoDiabetes.items()}

# age
total = sum(age_NoDiabetes.values())
prob_age_NoDiabetes  = {key: value / total for key, value in age_NoDiabetes.items()}

# %%
prob_Diabetes = 0.0
prob_NoDiabetes = 0.0

prob_Diabetes = np.count_nonzero(isDiabetes == 1) / len(isDiabetes)
prob_NoDiabetes = np.count_nonzero(isDiabetes == 0) / len(isDiabetes)

print(prob_Diabetes)
print(prob_NoDiabetes)
# Out:
# 0.3489583333333333
# 0.6510416666666666

# %%
### Saving the probabilities ###
import json

# %%
# to convert np data types into noraml datatypes for json file writing format
class NpEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        if isinstance(obj, np.floating):
            return float(obj)
        if isinstance(obj, np.ndarray):
            return obj.tolist()
        return super(NpEncoder, self).default(obj)

# %%
# prob_pregnancies_Diabetes
with open('/home/asif/DBMS-II/DiabetesPrediction/trainedData/prob_pregnancies_Diabetes.txt', 'w') as f: 
    f.write(json.dumps(prob_pregnancies_Diabetes), cls=NpEncoder)

# # prob_glucose_Diabetes
# with open('/home/asif/DBMS-II/DiabetesPrediction/trainedData/prob_glucose_Diabetes.txt', 'w') as f: 
#     for key, value in prob_glucose_Diabetes.items(): 
#         f.write('%s:%s\n' % (key, value))

# # prob_bloodPressure_Diabetes
# with open('/home/asif/DBMS-II/DiabetesPrediction/trainedData/prob_bloodPressure_Diabetes.txt', 'w') as f: 
#     for key, value in prob_bloodPressure_Diabetes.items(): 
#         f.write('%s:%s\n' % (key, value))

# # prob_skinThickness_Diabetes
# with open('/home/asif/DBMS-II/DiabetesPrediction/trainedData/prob_skinThickness_Diabetes.txt', 'w') as f: 
#     for key, value in prob_skinThickness_Diabetes.items(): 
#         f.write('%s:%s\n' % (key, value))
# # prob_insulin_Diabetes
# with open('/home/asif/DBMS-II/DiabetesPrediction/trainedData/prob_insulin_Diabetes.txt', 'w') as f: 
#     for key, value in prob_insulin_Diabetes.items(): 
#         f.write('%s:%s\n' % (key, value))

# # prob_bmi_Diabetes
# with open('/home/asif/DBMS-II/DiabetesPrediction/trainedData/prob_bmi_Diabetes.txt', 'w') as f: 
#     for key, value in prob_bmi_Diabetes.items(): 
#         f.write('%s:%s\n' % (key, value))

# # prob_diabetesPedigreeFunction_Diabetes 
# with open('/home/asif/DBMS-II/DiabetesPrediction/trainedData/prob_diabetesPedigreeFunction_Diabetes.txt', 'w') as f: 
#     for key, value in prob_diabetesPedigreeFunction_Diabetes.items(): 
#         f.write('%s:%s\n' % (key, value))

# # prob_age_Diabetes
# with open('/home/asif/DBMS-II/DiabetesPrediction/trainedData/prob_age_Diabetes.txt', 'w') as f: 
#     for key, value in prob_age_Diabetes.items(): 
#         f.write('%s:%s\n' % (key, value))

# %%
# prob_pregnancies_NoDiabetes
with open('/home/asif/DBMS-II/DiabetesPrediction/trainedData/prob_pregnancies_NoDiabetes.txt', 'w') as f: 
    for key, value in prob_pregnancies_NoDiabetes.items(): 
        f.write('%s:%s\n' % (key, value))

# prob_glucose_NoDiabetes
with open('/home/asif/DBMS-II/DiabetesPrediction/trainedData/prob_glucose_NoDiabetes.txt', 'w') as f: 
    for key, value in prob_glucose_NoDiabetes.items(): 
        f.write('%s:%s\n' % (key, value))

# prob_bloodPressure_NoDiabetes
with open('/home/asif/DBMS-II/DiabetesPrediction/trainedData/prob_bloodPressure_NoDiabetes.txt', 'w') as f: 
    for key, value in prob_bloodPressure_NoDiabetes.items(): 
        f.write('%s:%s\n' % (key, value))

# prob_skinThickness_NoDiabetes
with open('/home/asif/DBMS-II/DiabetesPrediction/trainedData/prob_skinThickness_NoDiabetes.txt', 'w') as f: 
    for key, value in prob_skinThickness_NoDiabetes.items(): 
        f.write('%s:%s\n' % (key, value))

# prob_insulin_NoDiabetes
with open('/home/asif/DBMS-II/DiabetesPrediction/trainedData/prob_insulin_NoDiabetes.txt', 'w') as f: 
    for key, value in prob_insulin_NoDiabetes.items(): 
        f.write('%s:%s\n' % (key, value))

# prob_bmi_NoDiabetes
with open('/home/asif/DBMS-II/DiabetesPrediction/trainedData/prob_bmi_NoDiabetes.txt', 'w') as f: 
    for key, value in prob_bmi_NoDiabetes.items(): 
        f.write('%s:%s\n' % (key, value))

# prob_diabetesPedigreeFunction_NoDiabetes 
with open('/home/asif/DBMS-II/DiabetesPrediction/trainedData/prob_diabetesPedigreeFunction_NoDiabetes.txt', 'w') as f: 
    for key, value in prob_diabetesPedigreeFunction_NoDiabetes.items(): 
        f.write('%s:%s\n' % (key, value))

# prob_age_NoDiabetes
with open('/home/asif/DBMS-II/DiabetesPrediction/trainedData/prob_age_NoDiabetes.txt', 'w') as f: 
    for key, value in prob_age_NoDiabetes.items(): 
        f.write('%s:%s\n' % (key, value))
